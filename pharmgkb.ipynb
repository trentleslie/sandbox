# %%
import requests
import json
import pandas as pd

genes = ['CYP2D6', 'ESR1', 'COMT', 
         'CYP3A5', 'ABCB1', 'CYP2C19', 
         'UGT2B7', 'SLC22A16', 'TPMT', 
         'NR1I2', 'NAT2', 'CYP1A2', 
         'CYP2C9', 'SULT1A1', 'UGT1A4', 
         'UGT1A8', 'UGT1A9', 'UGT2B15', 
         'UGT2B15', 'DPYD', 'TYMS', 
         'RRM1']

# variant annotation API
def get_variant_data(genes, url):
    # Create an empty DataFrame to hold the data
    all_data = pd.DataFrame()

    for gene in genes:
        
        # Make an API request for variant annotation data for the current gene
        # Set the parameters for the API request
        params = {
            "location.genes.symbol": gene,
            "view": "base"
        }
        
        try:
            # Make the API request
            response = requests.get(url, params=params)
            
             #Parse the JSON response
            data = response.json()
            
            # Convert the JSON response to a Pandas DataFrame
            gene_data = pd.json_normalize(data["data"])
            
            #print dimensions of the DataFrame
            print(gene, ":", gene_data.shape)

            # Append the gene data to the master DataFrame
            all_data = all_data.append(gene_data)
        except:
            print("Error: API request failed for gene " + gene)

        
        
    return all_data

#all_data = get_variant_data(genes, "https://api.pharmgkb.org/v1/data/variantAnnotation")

# Write the DataFrame to a CSV file
#all_data.to_csv("pharmagkb_variant.csv", index=False)

# Load the CSV file into a pandas DataFrame
all_data = pd.read_csv('pharmagkb_variant.csv')

#print dimensions of the DataFrame
print(all_data.shape)

print(",".join(all_data.columns))

all_data.head()
# Out:
# (8502, 131)
# id,accessionId,description,formatVersion,history,isAssociated,isPlural,objCls,pediatric,phenotypeCategories,populationPhenotypes,relatedChemicals,score,scoreDetails,sentence,studyParameters,useForCaScoring,connWords1.id,connWords1.resource,connWords1.term,connWords1.termId,drugsConnWord.id,drugsConnWord.resource,drugsConnWord.term,drugsConnWord.termId,literature.id,literature.title,literature._sameAs,literature.authors,literature.crossReferences,literature.journal,literature.month,literature.objCls,literature.page,literature.pediatric,literature.pgkbPublication,literature.pubDate,literature.terms,literature.volume,literature.year,location.id,location.copyNumber,location.diplotypes,location.displayName,location.genePhenotype.id,location.genePhenotype.resource,location.genePhenotype.term,location.genePhenotype.termId,location.genes,location.gpPosition,location.haplotypes,location.linkedObjects,location.refSeqPosition,location.tagGene,location.type,location.variant.objCls,location.variant.id,location.variant.name,metabolizer1.id,metabolizer1.resource,metabolizer1.term,metabolizer1.termId,metabolizer2.id,metabolizer2.resource,metabolizer2.term,metabolizer2.termId,polarity.id,polarity.resource,polarity.term,polarity.termId,populationTerm.id,populationTerm.resource,populationTerm.term,populationTerm.termId,significance.id,significance.resource,significance.term,significance.termId,alleleGenotype,assayType,comparison,objects,cell,phenotypes,connWords2.id,connWords2.resource,connWords2.term,connWords2.termId,phenotypeLinksConnWord.id,phenotypeLinksConnWord.resource,phenotypeLinksConnWord.term,phenotypeLinksConnWord.termId,populationPhenotypeLinksConnWord.id,populationPhenotypeLinksConnWord.resource,populationPhenotypeLinksConnWord.term,populationPhenotypeLinksConnWord.termId,geneSymbol,location.buildVersion,location.chromosomeId,location.chromosomeName,location.refSeqCrossReference.id,location.refSeqCrossReference.resource,location.refSeqCrossReference.resourceId,location.refSeqCrossReference._url,location.rsid,location.variant.symbol,sequenceLocation.id,sequenceLocation.assembly,sequenceLocation.begin,sequenceLocation.end,sequenceLocation.intronicOffset,sequenceLocation.referenceAllele,sequenceLocation.referenceHgvs,sequenceLocation.sequence.id,sequenceLocation.sequence.name,sequenceLocation.sequence.resource,sequenceLocation.sequence.resourceId,sequenceLocation.sequence._url,sequenceLocation.source,sequenceLocation.type,sequenceLocation.variantAlleles,sequenceLocation.variantHgvs,scoringRationale,location.refSeqCrossReference.name,sequenceLocation.altHgvs.c,sequenceLocation.altHgvs.g,sequenceLocation.altHgvs.name,sequenceLocation.altHgvs.p,alleleGroupingDescription,sequenceLocation.altHgvs.p.desc,sequenceLocation.notes
# c:\Users\trent\anaconda3\envs\Springboard\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (38,63,64,65,124,125,126,127,128,129) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            id  accessionId                                        description  \
# 0  1183684657  PA166145182  Median (+)R,R-tramadol area under the curve wa...
# 1  1183684661  PA166144530  Median (+)R,R-tramadol area under the curve wa...
# 2  1450042177  PA166181190  Intrinsic clearance was 11.8% that of CYP2D6*1...
# 3   982047744  PA166143228  A 2 year old boy with an ultrarapid-metabolize...
# 4  1451152848  PA166210941  Healthy volunteers were previously phenotyped ...
#
#    formatVersion                                            history  \
# 0              1  [{'id': 1450367381, 'date': '2019-01-29T09:19:...
# 1              1  [{'id': 1450367377, 'date': '2019-01-29T09:19:...
# 2              1  [{'id': 1450042184, 'date': '2018-11-14T11:30:...
# 3              1                                                 []
# 4              2                                                 []
#
#    isAssociated  isPlural                               objCls  pediatric  \
# 0          True     False              Variant Drug Annotation      False
# 1          True     False              Variant Drug Annotation      False
# 2          True     False  Variant Functional Assay Annotation      False
# 3          True     False              Variant Drug Annotation      False
# 4          True     False              Variant Drug Annotation      False
#
#                                  phenotypeCategories  ...  \
# 0  [{'id': 981344088, 'resource': 'Phenotype Cate...  ...
# 1  [{'id': 981344088, 'resource': 'Phenotype Cate...  ...
# 2  [{'id': 981344088, 'resource': 'Phenotype Cate...  ...
# 3  [{'id': 981344088, 'resource': 'Phenotype Cate...  ...
# 4  [{'id': 981344088, 'resource': 'Phenotype Cate...  ...
#
#   sequenceLocation.variantHgvs scoringRationale  \
# 0                          NaN              NaN
# 1                          NaN              NaN
# 2                          NaN              NaN
# 3                          NaN              NaN
# 4                          NaN              NaN
#
#    location.refSeqCrossReference.name sequenceLocation.altHgvs.c  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
#
#   sequenceLocation.altHgvs.g sequenceLocation.altHgvs.name  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#    sequenceLocation.altHgvs.p  alleleGroupingDescription  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#   sequenceLocation.altHgvs.p.desc sequenceLocation.notes
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
#
# [5 rows x 131 columns]

# %%
# Create a list of the columns of interest
cols_of_interest = ["id",
                    "accessionId",
                    "alleleGenotype", 
                    "geneSymbol", 
                    "drugsConnWord.term", 
                    "phenotypes", 
                    "location.variant.symbol", 
                    "sequenceLocation.variantHgvs"]

# Use the loc method to keep only the columns of interest
all_data_variant = all_data.loc[:, cols_of_interest]

# Print the resulting DataFrame
all_data_variant.head()
# Out:
#            id  accessionId alleleGenotype geneSymbol drugsConnWord.term  \
# 0  1183684657  PA166145182            NaN        NaN                and
# 1  1183684661  PA166144530            NaN        NaN                and
# 2  1450042177  PA166181190            *10        NaN                 or
# 3   982047744  PA166143228           *1xN        NaN                and
# 4  1451152848  PA166210941            NaN        NaN                NaN
#
#   phenotypes location.variant.symbol sequenceLocation.variantHgvs
# 0        NaN                     NaN                          NaN
# 1        NaN                     NaN                          NaN
# 2        NaN                     NaN                          NaN
# 3        NaN                     NaN                          NaN
# 4        NaN                     NaN                          NaN

# %%
# drug label annotation API
def get_drug_label_data(url):
    # Create an empty DataFrame to hold the data
    all_data = pd.DataFrame()

    #for id in ids:
        
    #this_url = url + str(id)
    this_url = url
    print(this_url)
        
    # Make an API request for variant annotation data for the current gene
    # Set the parameters for the API request
    params = {
        #"relatedGenes.symbol": id,
        "relatedChemicals.name": "tamoxifen",
        "view": "base"
    }
    
    try:
        # Make the API request
        response = requests.get(this_url, params=params)

        #Parse the JSON response
        data = response.json()
        
        # Convert the JSON response to a Pandas DataFrame
        gene_data = pd.json_normalize(data["data"])
        
        #print dimensions of the DataFrame
        #print(id, ":", gene_data.shape)

        # Append the gene data to the master DataFrame
        all_data = all_data.append(gene_data)
        
    except:
        print("Error: API request failed for gene " + str(id))

        
        
    return all_data

all_data_drug_label = get_drug_label_data("https://api.pharmgkb.org/v1/data/label/")    

# Write the DataFrame to a CSV file
all_data_drug_label.to_csv("pharmagkb_drug_label.csv", index=False)

#print dimensions of the DataFrame
print(all_data_drug_label.shape)

all_data_drug_label.head()
# Out:
# https://api.pharmgkb.org/v1/data/label/
# (5, 28)
#              objCls           id  \
# 0  Label Annotation  PA166104819
# 1  Label Annotation  PA166184392
# 2  Label Annotation  PA166170936
# 3  Label Annotation  PA166181925
# 4  Label Annotation  PA166127718
#
#                                                 name  alternateDrugAvailable  \
# 0  Annotation of FDA Label for tamoxifen and ESR1...                    True
# 1  Annotation of Swissmedic Label for tamoxifen a...                   False
# 2   Annotation of FDA Label for tamoxifen and F2, F5                   False
# 3   Annotation of FDA Label for tamoxifen and CYP2D6                   False
# 4  Annotation of HCSC Label for tamoxifen and CYP...                   False
#
#          biomarkerStatus  cancerGenome crossReferences  dosingInformation  \
# 0  On FDA Biomarker List          True              []              False
# 1                    NaN         False              []              False
# 2  On FDA Biomarker List         False              []              False
# 3  On FDA Biomarker List         False              []              False
# 4                    NaN         False              []              False
#
#                                              history  \
# 0  [{'id': 1183681483, 'date': '2013-10-25T11:41:...
# 1                                                 []
# 2                                                 []
# 3  [{'id': 1450821494, 'date': '2019-10-09T14:37:...
# 4                                                 []
#
#                                    labelApplications  ...  \
# 0  [{'id': 1449814265, 'onOpenFda': True, 'pgxPre...  ...
# 1                                                 []  ...
# 2  [{'id': 1449814158, 'onOpenFda': True, 'pgxPre...  ...
# 3  [{'id': 1450369807, 'onOpenFda': True, 'pgxPre...  ...
# 4                                                 []  ...
#
#                             prescribingMarkdown.html  summaryMarkdown.id  \
# 0  <p>Excerpt from the tamoxifen (SOLTAMOX) drug ...          1447981618
# 1                                                NaN          1450815403
# 2                                                NaN          1449052557
# 3                                                NaN          1450369804
# 4                                                NaN          1447982367
#
#                                 summaryMarkdown.html  testing.id  \
# 0  <p>Tamoxifen (SOLTAMOX) is an anti-estrogen us...  1183672041
# 1  <p>The Swiss drug label for tamoxifen (Nolvade...  1183672111
# 2  <p>Tamoxifen (SOLTAMOX) is indicated for the t...  1183672141
# 3  <p>The FDA-approved drug label for tamoxifen (...  1183672111
# 4  <p>The product monograph for tamoxifen states ...  1183672041
#
#         testing.resource      testing.term            testing.termId  \
# 0  Genetic Testing Level  Testing required  geneTestLevel:1183672041
# 1  Genetic Testing Level    Actionable PGx  geneTestLevel:1183672111
# 2  Genetic Testing Level   Informative PGx  geneTestLevel:1183672141
# 3  Genetic Testing Level    Actionable PGx  geneTestLevel:1183672111
# 4  Genetic Testing Level  Testing required  geneTestLevel:1183672041
#
#    textMarkdown.id                                  textMarkdown.html  \
# 0       1447981617  <p>Excerpts from the tamoxifen (SOLTAMOX) drug...
# 1       1450815404  <p><strong>Please note that the information co...
# 2       1449052556  <p>Excerpt from the tamoxifen (SOLTAMOX) drug ...
# 3       1450369805  <p>Excerpt from the tamoxifen (SOLTAMOX) drug ...
# 4       1447982366  <p>Excerpts from the tamoxifen product monogra...
#
#    fdaPgxAssociation
# 0                NaN
# 1                NaN
# 2                NaN
# 3                 PK
# 4                NaN
#
# [5 rows x 28 columns]

# %%
response.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-95cf7eee0132> in <module>
# ----> 1 response.text
#
# NameError: name 'response' is not defined

# %%
all_data_drug_label.columns
# Out:
# Index(['objCls', 'id', 'name', 'alternateDrugAvailable', 'biomarkerStatus',
#        'cancerGenome', 'crossReferences', 'dosingInformation',
#        'fdaPgxAssociation', 'history', 'labelApplications', 'literature',
#        'pediatric', 'prescribingGenes', 'relatedAlleles', 'relatedChemicals',
#        'relatedGenes', 'source', 'prescribingMarkdown.id',
#        'prescribingMarkdown.html', 'summaryMarkdown.id',
#        'summaryMarkdown.html', 'testing.id', 'testing.resource',
#        'testing.term', 'testing.termId', 'textMarkdown.id',
#        'textMarkdown.html', 'pediatricMarkdown.id', 'pediatricMarkdown.html',
#        'retirementReason.id', 'retirementReason.resource',
#        'retirementReason.term', 'retirementReason.termId', 'errors'],
#       dtype='object')

# %%
# Set the API endpoint URL
url = "https://api.pharmgkb.org/v1/data/label"

# Set the parameters for the API request
params = {
    "levelOfEvidence.term": "1A",
    "view": "base"
}

# Make the API request
response = requests.get(url, params=params)

# Parse the JSON response
data = response.json()

# Normalize the JSON data into a Pandas DataFrame
df_clin = pd.json_normalize(data["data"])

# Write the DataFrame to a CSV file
df_clin.to_csv("pharmagkb_clin.csv", index=False)

# Print a confirmation message
print("DataFrame written to output.csv")

#print dimensions of the DataFrame
print(df_clin.shape)

df_clin.head()
# Out:
# DataFrame written to output.csv
# (289, 46)
#            id  accessionId                                   allelePhenotypes  \
# 0  1445117525  PA166136351  [{'id': 1451333059, 'allele': 'CC', 'limitedEv...
# 1  1183705788  PA166135464  [{'id': 1451332933, 'allele': 'CC', 'limitedEv...
# 2  1445400186  PA166135876  [{'id': 1451333191, 'allele': 'AA', 'limitedEv...
# 3  1451434920  PA166242001  [{'id': 1451461447, 'allele': 'A', 'limitedEvi...
# 4  1445400222  PA166136355  [{'id': 1451333198, 'allele': 'GG', 'limitedEv...
#
#   conflictingVariantAnnotationIds  \
# 0                              []
# 1                              []
# 2                              []
# 3                              []
# 4                              []
#
#                                              history  \
# 0  [{'id': 1445117526, 'date': '2015-07-23T14:19:...
# 1  [{'id': 1447992478, 'date': '2016-05-27T16:43:...
# 2  [{'id': 1445400187, 'date': '2015-07-30T16:02:...
# 3  [{'id': 1451434924, 'date': '2021-05-10T17:03:...
# 4  [{'id': 1445400223, 'date': '2015-07-30T16:36:...
#
#                                                 name               objCls  \
# 0  Clinical Annotation for rs193922876 (RYR1); de...  Clinical Annotation
# 1  Clinical Annotation for rs118192170 (RYR1); de...  Clinical Annotation
# 2  Clinical Annotation for rs1801086 (RYR1); desf...  Clinical Annotation
# 3  Clinical Annotation for rs267606617 (MT-RNR1);...  Clinical Annotation
# 4  Clinical Annotation for rs193922772 (RYR1); de...  Clinical Annotation
#
#    overrideLevel  pediatric  \
# 0          False       True
# 1          False      False
# 2          False       True
# 3          False       True
# 4          False       True
#
#                                     relatedChemicals  ...  \
# 0  [{'objCls': 'Chemical', 'id': 'PA164749136', '...  ...
# 1  [{'objCls': 'Chemical', 'id': 'PA164749136', '...  ...
# 2  [{'objCls': 'Chemical', 'id': 'PA164749136', '...  ...
# 3  [{'objCls': 'Chemical', 'id': 'PA164744372', '...  ...
# 4  [{'objCls': 'Chemical', 'id': 'PA164749136', '...  ...
#
#                   location.refSeqCrossReference._url location.refSeqPosition  \
# 0  https://www.ncbi.nlm.nih.gov/nuccore/NC_000019.10                38580114
# 1  https://www.ncbi.nlm.nih.gov/nuccore/NC_000019.10                38584989
# 2  https://www.ncbi.nlm.nih.gov/nuccore/NC_000019.10                38446710
# 3   https://www.ncbi.nlm.nih.gov/nuccore/NC_012920.1                    1555
# 4  https://www.ncbi.nlm.nih.gov/nuccore/NC_000019.10                38457546
#
#   location.rsid location.tagGene  location.type location.variant.objCls  \
# 0   rs193922876            False            SNP                 Variant
# 1   rs118192170            False            SNP                 Variant
# 2     rs1801086            False            SNP                 Variant
# 3   rs267606617            False            SNP                 Variant
# 4   rs193922772            False            SNP                 Variant
#
#   location.variant.id  location.variant.symbol location.variant.name  \
# 0         PA166155575              rs193922876           rs193922876
# 1         PA166155536              rs118192170           rs118192170
# 2         PA166155375                rs1801086             rs1801086
# 3         PA166159181              rs267606617           rs267606617
# 4         PA166155568              rs193922772           rs193922772
#
#   overrideLevelDescription
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 46 columns]

# %%
df_clin.columns
# Out:
# Index(['id', 'accessionId', 'allelePhenotypes',
#        'conflictingVariantAnnotationIds', 'history', 'name', 'objCls',
#        'overrideLevel', 'pediatric', 'relatedChemicals',
#        'relatedChemicalsLogic', 'relatedDiseases', 'relatedGuidelines',
#        'relatedLabels', 'score', 'scoreDetails', 'types', 'levelOfEvidence.id',
#        'levelOfEvidence.resource', 'levelOfEvidence.term',
#        'levelOfEvidence.termId', 'location.id', 'location.buildVersion',
#        'location.chromosomeId', 'location.chromosomeName',
#        'location.copyNumber', 'location.diplotypes', 'location.displayName',
#        'location.genes', 'location.gpPosition', 'location.haplotypes',
#        'location.linkedObjects', 'location.refSeqCrossReference.id',
#        'location.refSeqCrossReference.name',
#        'location.refSeqCrossReference.resource',
#        'location.refSeqCrossReference.resourceId',
#        'location.refSeqCrossReference._url', 'location.refSeqPosition',
#        'location.rsid', 'location.tagGene', 'location.type',
#        'location.variant.objCls', 'location.variant.id',
#        'location.variant.symbol', 'location.variant.name',
#        'overrideLevelDescription'],
#       dtype='object')
